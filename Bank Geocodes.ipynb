# %%
api_key='AIzaSyDjbQHOGFHjxaZbYaHVlqV3C_oJwIjPVY0'

# %%
import googlemaps

# %%
gm=googlemaps.Client(key=api_key)

# %%
# geocode_result=gm.geocode('WARDX,KADAMPANADVILLAGE,MANNADYPO,PATHANAMTHITTADISTRICT,KERALA-691530')[0]
# # geocode_result['geometry']['location']
# geocode_result
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-e6388312ea2d> in <module>()
# ----> 1 geocode_result=gm.geocode('WARDX,KADAMPANADVILLAGE,MANNADYPO,PATHANAMTHITTADISTRICT,KERALA-691530')[0]
#       2 # geocode_result['geometry']['location']
#       3 geocode_result
#
# IndexError: list index out of range

# %%
import pandas as pd
colnames=['BANK','ADDRESS','CITY','DISTRICT','STATE']
df1 = pd.read_excel("C:/Users/mohinder/Data Analysis and M.Learning/Bank/IFCB2009_35.xlsx", usecols=colnames,encoding = "ISO-8859-1")
df1=df1.head(625)
df2 = pd.read_excel("C:/Users/mohinder/Data Analysis and M.Learning/Bank/IFCB2009_55.xlsx", usecols=colnames,encoding = "ISO-8859-1")
df2=df2.head(625)
df3 = pd.read_excel("C:/Users/mohinder/Data Analysis and M.Learning/Bank/IFCB2009_59.xlsx", usecols=colnames,encoding = "ISO-8859-1")
df3=df3.head(625)
df4 = pd.read_excel("C:/Users/mohinder/Data Analysis and M.Learning/Bank/IFCB2009_68.xlsx", usecols=colnames,encoding = "ISO-8859-1")
df4=df4.head(625)
df=df1.append(df2)
df=df.append(df3)
df=df.append(df4)
df
# Out:
#                     BANK                                            ADDRESS  \
# 0     ICICI BANK LIMITED  ICICI BANK TOWERS, BANDRA KURLA COMPLEX, MUMBA...
# 1     ICICI BANK LIMITED  ICICI BANK TOWERS, BANDRA KURLA COMPLEX, BANDR...
# 2     ICICI BANK LIMITED  ZILA SAHAKARI BANK LTD,  275, INDIRA COMPLEX, ...
# 3     ICICI BANK LIMITED  MAIN BRANCH BADRINATH MARG, KOTDWARA, UTTARAKH...
# 4     ICICI BANK LIMITED         JAGDISH BUILDING HAZRATGANJ LUCKNOW 226001
# 5     ICICI BANK LIMITED           156/1 CIVIL LINES JHANSI (U.P) -  284001
# 6     ICICI BANK LIMITED                       NEAR KACHERA,GHAZIPUR-233001
# 7     ICICI BANK LIMITED  ICICI BANK LTD.,H.O., SHAHJAHANPUR ROAD, NEAR ...
# 8     ICICI BANK LIMITED      NEAR NAGAR PALIKA,CIVIL LINES,AZAMGARH-276001
# 9     ICICI BANK LIMITED                      COLLECTORATE COMPOUND,JAUNPUR
# 10    ICICI BANK LIMITED  ZILA SAHAKARI BANK LIMITED HARIDWAR, H.O.- B.T...
# ...

# %%
df.iloc[1099,0]
# Out:
# 'ORIENTAL BANK OF COMMERCE'

# %%
colnames=['BANK','ADDRESS','CITY','DISTRICT','STATE',"lat","lon"]
df_final = pd.DataFrame(columns=colnames)
for index,row in df4.iterrows():
    if(index>200):
        break
    #print(row['ADDRESS'])
    try:
        geocode_result=gm.geocode(row['ADDRESS'])[0]
        df_final.loc[index,'BANK']=row['BANK']
        df_final.loc[index,'ADDRESS']=row['ADDRESS']
        df_final.loc[index,'CITY']=row['CITY']
        df_final.loc[index,'DISTRICT']=row['DISTRICT']
        df_final.loc[index,'STATE']=row['STATE']
        df_final.loc[index,'lat']=geocode_result['geometry']['location'].get('lat')
        df_final.loc[index,'lon']=geocode_result['geometry']['location'].get('lng')
    except IndexError:
        a=2
    except HTTPError:
        b=4
#     geocode_result=gm.geocode(row['ADDRESS'])[0]
#     print(geocode_result['geometry']['location'])

# %%
df_final
# Out:
#                     BANK                                            ADDRESS  \
# 3    STATE BANK OF INDIA  S.J.PALACE, GOPALNAGAR, DHEBARBHAI ROAD,RAJKOT...
# 4    STATE BANK OF INDIA                 HEAD OFFICE, MOHADDIPUR, GORAKHPUR
# 5    STATE BANK OF INDIA  OPP. WAR CEMETERY,KOHIMA TOWN, P.O. KOHIMA. PI...
# 6    STATE BANK OF INDIA  MIZORAM RURAL BANK, HEAD OFFICE  B 5, BABU TIL...
# 7    STATE BANK OF INDIA  HEAD OFFICE, M.T.C BUILDING, 2ND FLOOR, POLICE...
# 10   STATE BANK OF INDIA  SIR SYED MARKET, WAZIR BAGH  SRINAGAR  KASHMIR...
# 13   STATE BANK OF INDIA  ASHOKA COMPLEX,HANUMAKONDA,WARANGAL DIST,ANDRA...
# 14   STATE BANK OF INDIA  SBI GLOBAL IT CENTRE;CBD BELAPUR;NAVI MUMBAI 4...
# 15   STATE BANK OF INDIA  PAYMENT SYSTEMS GROUP,STATE BANK GITC,CBD BELA...
# 18   STATE BANK OF INDIA  HOUSINGBOARDBUILDING,SANTHINAGAR,THIRUVANANTHA...
# 19   STATE BANK OF INDIA  SBTBHAVAN,PANAMPILLYNAGAR,ERNAKULAMDISTRICT,KE...
# ...

# %%
df_final.to_csv("C:/Users/mohinder/Data Analysis and M.Learning/Bank/bank_lonlat3.csv", sep=',')

# %%
try:
    geocode_result=gm.geocode('Warangal')[0]
    print(geocode_result)
except IndexError:
    print("ohhh")
# if(len(geocode_result)!=0):
#     try:
#         print(geocode_result['geometry']['location'])
#     except IndexError:
#         print("ohhh")
# Out:
# {'address_components': [{'long_name': 'Warangal', 'short_name': 'Warangal', 'types': ['locality', 'political']}, {'long_name': 'Warangal', 'short_name': 'Warangal', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Telangana', 'short_name': 'Telangana', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'India', 'short_name': 'IN', 'types': ['country', 'political']}], 'formatted_address': 'Warangal, Telangana, India', 'geometry': {'bounds': {'northeast': {'lat': 18.0169363, 'lng': 79.65225219999999}, 'southwest': {'lat': 17.8993616, 'lng': 79.5561218}}, 'location': {'lat': 17.9689008, 'lng': 79.59405439999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 18.0169363, 'lng': 79.65225219999999}, 'southwest': {'lat': 17.8993616, 'lng': 79.5561218}}}, 'place_id': 'ChIJ50te1wtFMzoRN8F7J5yQBpM', 'types': ['locality', 'political']}

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
m=Basemap(projection='mill',llcrnrlat=6,urcrnrlat=36,llcrnrlon=70,urcrnrlon=98,resolution='c',epsg=4269)
plt.figure(figsize=(20,10))
m.arcgisimage(service="NatGeo_World_Map", verbose=True)
# m.bluemarble()
lat = 19.0621810197085
lon = 72.86261201970852
x,y = m(lon, lat)
m.plot(x,y,'yo',markersize=10)
lat = 30.0621810197085
lon = 76.86261201970852
x,y = m(lon, lat)
m.plot(x,y,'bo',markersize=10)
plt.show()
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/export?bbox=70.0,6.000000000000001,98.00000000000001,36.0&bboxSR=4269&imageSR=4269&size=400,428&dpi=96&format=png32&f=image
# C:\Users\mohinder\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3310: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# C:\Users\mohinder\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3319: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# C:\Users\mohinder\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3274: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# C:\Users\mohinder\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3283: MatplotlibDeprecationWarning: axes.hold is deprecated.
# ...
